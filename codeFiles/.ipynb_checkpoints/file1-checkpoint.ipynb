# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %%
ar1 = [1,2,3,4]
ar1.append?

# %%
ar1
# Out:
# [1, 2, 3, 4]

# %%
*Warning?

# %% [markdown]
# # Testing out the MarkDown

# %%
# %timeit l = [n**2 for n in range(500)]
# Out:
# 105 µs ± 176 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
print(In)
# Out:
# ['', 'help(len)', "get_ipython().run_line_magic('pinfo', 'len')", "get_ipython().run_line_magic('pinfo', 'len')\nar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1.append')", "get_ipython().run_line_magic('pinfo', 'len')\nar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1.append')", "get_ipython().run_line_magic('pinfo', 'len')", "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1.append')", 'ar1 = [1,2,3,4]\narr1.append()?', "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1.append')", "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1.append')", "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1.insert')", "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'arr1')", "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'ar1.append')", "ar1 = [1,2,3,4]\nget_ipython().run_line_magic('pinfo', 'ar1.append')", 'ar1', "get_ipython().run_line_magic('psearch', '*warning')", "get_ipython().run_line_magic('psearch', '*Warn
# ...

# %%
print(Out)
# Out:
# {14: [1, 2, 3, 4]}

# %% [markdown]
# # To hide the output of the code block

# %% [markdown]
# ### Just add semicolon at the end

# %%
_;
