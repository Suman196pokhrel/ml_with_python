# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '1.3.4'

# %%
pd?

# %% [markdown]
# ## Pandas Series

# %%
data = pd.Series([11,22,33,44,55,66])
data
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# dtype: int64

# %%
data.values
# Out:
# array([11, 22, 33, 44, 55, 66], dtype=int64)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
data[0]
# Out:
# 11

# %%
data[2:]
# Out:
# c    33
# d    44
# e    55
# f    66
# dtype: int64

# %% [markdown]
# ## Series as generalized numpy arrays

# %%
data = pd.Series([11,22,33,44,55,66],index=['a','b','c','d','e','f'])
data
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# f    66
# dtype: int64

# %%
data['c']
# Out:
# 33

# %% [markdown]
# ## Series as specialized dictionary

# %%
population_dict = {
    'California':38332521,
    'Texas': 26448193,
    'New York': 19651127,
    'Florida': 19552860,
    'Illinois': 12882135
}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population['California': 'Florida']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# dtype: int64

# %% [markdown]
# ## Pandas DataFrame Object

# %% [markdown]
# ### Dataframe as a generalized Numpy Array

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
 'Florida': 170312, 'Illinois': 149995}
area_dict
# Out:
# {'California': 423967,
#  'Texas': 695662,
#  'New York': 141297,
#  'Florida': 170312,
#  'Illinois': 149995}

# %%
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({'population':population,
                      'area':area})
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.values
# Out:
# array([[38332521,   423967],
#        [26448193,   695662],
#        [19651127,   141297],
#        [19552860,   170312],
#        [12882135,   149995]], dtype=int64)

# %% [markdown]
# ### Dataframe as specialized dictionary

# %%
states['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %% [markdown]
# ### Constructing Dataframe objects from Dictionary of Series

# %%
states = pd.DataFrame({'population':population,
                      'area':area})
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %% [markdown]
# ### Constructing Dataframe objects from list of Dicts

# %%
data = [{'a': i, 'b': 2 * i}for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %% [markdown]
# ### From 2-D Numpy Array

# %%
pd.DataFrame(np.random.random((3,2)), columns=['foo','bar'],index =['a','b','c'])
# Out:
#         foo       bar
# a  0.379283  0.377566
# b  0.160275  0.515537
# c  0.672534  0.903098
