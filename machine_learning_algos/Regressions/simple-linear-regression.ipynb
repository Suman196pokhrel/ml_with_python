# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/placement_package.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
fig, ax =plt.subplots()

ax.scatter(df['cgpa'],df['package'])
ax.set_xlabel("CGPA")
ax.set_ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
X = df.iloc[:,0:1]
Y = df.iloc[:,-1]
X.shape
# Out:
# (200, 1)

# %%
from  sklearn.model_selection  import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=40)
X_train.head()
# Out:
#      cgpa
# 86   7.61
# 182  5.88
# 69   7.30
# 125  7.33
# 42   5.95

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\spokh\AppData\Local\Programs\Python\pythonEnvs\mlEnv\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.08765691])

# %%
fig, ax = plt.subplots()

ax.scatter(df['cgpa'],df['package'])
ax.plot(X_train,lr.predict(X_train),c='red')

ax.set_xlabel("CGPA")
ax.set_ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')
