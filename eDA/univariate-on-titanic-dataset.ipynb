# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../datasets/Titanic-Dataset.csv")
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 432          433         1       2
# 172          173         1       3
# 272          273         1       2
# 442          443         0       3
# 833          834         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 432  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 172                       Johnson, Miss. Eleanor Ileen  female   1.0      1
# 272          Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0      0
# 442                          Petterson, Mr. Johan Emil    male  25.0      1
# 833                             Augustsson, Mr. Albert    male  23.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 432      0  SC/AH 3085  26.0000   NaN        S
# 172      1      347742  11.1333   NaN        S
# 272      1      250644  19.5000   NaN        S
# 442      0      347076   7.7750   NaN        S
# 833      0      347468   7.8542   NaN        S

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### a.Countplot

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(x=df["Survived"])
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=df["Pclass"])
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ### 2. Piechart

# %%
df["Survived"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='Survived'>

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='Pclass'>

# %% [markdown]
# # 2. Numerical data

# %% [markdown]
# ## a. Histogram - to understand Distribution of Data

# %%
plt.hist(df["Age"])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## b. Distplot

# %%
sns.displot(df["Age"],kde=True,rug=False)

# %% [markdown]
# ### c. Boxplot -gives you 5 number summary- for picking out noise in your data

# %%
 sns.boxplot(df["Age"],orient="h")
# Out:
# <AxesSubplot: >

# %%
df["Age"].min(),df["Age"].max(),df["Age"].mean(),df["Age"].skew()
# Out:
# (0.42, 80.0, 29.69911764705882, 0.38910778230082704)
