# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = pd.read_csv('../datasets/orders.csv')
time = pd.read_csv('../datasets/messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# ### convert the dtype into date-time from object

# %% [markdown]
# ## Working with Dates

# %%
date['date'] = pd.to_datetime(date['date'])
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# ### 1. Extract Year

# %%
date['date_year'] = date['date'].dt.year
date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-01-06        4344       25       3       2019

# %% [markdown]
# ### 2. Extract Month

# %%
date['date_month_no'] =  date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1

# %% [markdown]
# ### 3. Extract Month Name

# %%
date['date_month_name'] =  date['date'].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name
# 0        December
# 1          August
# 2         October
# 3          August
# 4         January

# %% [markdown]
# ### 4. Extract Days

# %%
date['date_days'] = date['date'].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_days
# 0        December         10
# 1          August         15
# 2         October         23
# 3          August         17
# 4         January          6

# %% [markdown]
# ### 5. Day of Week

# %%
date['date_day_of_week'] = date['date'].dt.dayofweek
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_days  date_day_of_week
# 0        December         10                 1
# 1          August         15                 2
# 2         October         23                 1
# 3          August         17                 5
# 4         January          6                 6

# %% [markdown]
# ### 6. Is weekend

# %%
date['date_is_weekend'] = np.where(date['date_day_of_week'].isin(['Sunday','Saturday']),1,0)
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_days  date_day_of_week  date_is_weekend
# 0        December         10                 1                0
# 1          August         15                 2                0
# 2         October         23                 1                0
# 3          August         17                 5                0
# 4         January          6                 6                0

# %% [markdown]
# ### 7. Extract Week of the Year

# %%
date['date_week_of_year'] = date['date'].dt.week
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
# /tmp/ipykernel_5040/3142194335.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['date_week_of_year'] = date['date'].dt.week
#         date  date_year  date_month_no date_month_name  date_days  \
# 0 2019-12-10       2019             12        December         10
# 1 2018-08-15       2018              8          August         15
# 2 2018-10-23       2018             10         October         23
# 3 2019-08-17       2019              8          August         17
# 4 2019-01-06       2019              1         January          6
#
#    date_day_of_week  date_is_weekend  date_week_of_year
# 0                 1                0                 50
# 1                 2                0                 33
# 2                 1                0                 43
# 3                 5                0                 33
# 4                 6                0                  1

# %% [markdown]
# ### 8 . Extract Quater

# %%
date['date_quarter'] = date['date'].dt.quarter
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_days  date_day_of_week  date_is_weekend  \
# 0        December         10                 1                0
# 1          August         15                 2                0
# 2         October         23                 1                0
# 3          August         17                 5                0
# 4         January          6                 6                0
#
#    date_week_of_year  date_quarter
# 0                 50             4
# 1                 33             3
# 2                 43             4
# 3                 33             3
# 4                  1             1

# %% [markdown]
# ### 9. Extract Semester

# %%
date['date_semester'] = np.where(date['date_quarter'].isin(['1,2']),1,2)
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_days  date_day_of_week  date_is_weekend  \
# 0        December         10                 1                0
# 1          August         15                 2                0
# 2         October         23                 1                0
# 3          August         17                 5                0
# 4         January          6                 6                0
#
#    date_week_of_year  date_quarter  date_semester
# 0                 50             4              2
# 1                 33             3              2
# 2                 43             4              2
# 3                 33             3              2
# 4                  1             1              2

# %% [markdown]
# ### 10. Extract time elapsed between two dates

# %%
import datetime

today  = datetime.datetime.today()

today - date['date']
# Out:
# 0     1098 days 21:18:12.192392
# 1     1580 days 21:18:12.192392
# 2     1511 days 21:18:12.192392
# 3     1213 days 21:18:12.192392
# 4     1436 days 21:18:12.192392
#                  ...
# 995   1526 days 21:18:12.192392
# 996   1467 days 21:18:12.192392
# 997   1315 days 21:18:12.192392
# 998   1380 days 21:18:12.192392
# 999   1154 days 21:18:12.192392
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      1098
# 1      1580
# 2      1511
# 3      1213
# 4      1436
#        ...
# 995    1526
# 996    1467
# 997    1315
# 998    1380
# 999    1154
# Name: date, Length: 1000, dtype: int64

# %% [markdown]
# #### Same operations can be applied to time dataframe and attributes of dt such as hour, minutes, second can be extracted
